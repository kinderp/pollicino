# %% [markdown]
# # POLLICINO UDA 6 — dal modello ai bit reali
# Range coding, formato `.pol`, overhead e verifica lossless.

# %%
import math
for p in [0.5,0.25,0.125,1/256]: print(p, -math.log2(p))

# %% [markdown]
# ## Regola
# Il payload ideale non basta: un benchmark reale conta header, metadati/modello e verifica round-trip.
