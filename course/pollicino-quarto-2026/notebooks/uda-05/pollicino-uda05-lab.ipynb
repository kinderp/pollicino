# %% [markdown]
# # POLLICINO UDA 5 — PyTorch e MLX
# Stessa ModelSpec, due backend, stessa metrica bits-per-byte.

# %%
import math
uniform_bpb = -math.log2(1/256)
uniform_bpb

# %% [markdown]
# ## Contratto sperimentale
# Registra seed, versioni, hardware, parametri, training time, validation loss e validation bpb. Non confrontare run con ModelSpec diverse.
